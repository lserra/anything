# %% [markdown]
# ### Pandas Cookbook - Chapter 1
# ---------------------------------------
# Fonte: https://github.com/jvns/pandas-cookbook

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)
# Out:
# /home/laercio.serra/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
plt.style.use('default')

# %%
plt.rcParams['figure.figsize'] = (15, 5)

# %%
path = '/home/laercio.serra/Temp/'
filename = 'bikes.csv'

# %%
broken_df = pd.read_csv(path+filename)

# %%
broken_df.head()
# Out:
#   Date\tBerri 1\tBrébeuf\tCôte-Sainte-Catherine\tMaisonneuve 1\tMaisonneuve 2\tdu Parc\tPierre-Dupuy\tRachel1\tSt-Urbain
# 0          01/01/2012\t35\t\t0\t38\t51\t26\t10\t16\t
# 1          02/01/2012\t83\t\t1\t68\t153\t53\t6\t43\t
# 2        03/01/2012\t135\t\t2\t104\t248\t89\t3\t58\t
# 3       04/01/2012\t144\t\t1\t116\t318\t111\t8\t61\t
# 4       05/01/2012\t197\t\t2\t124\t330\t97\t13\t95\t

# %%
fixed_df = pd.read_csv(path+filename, sep='\t', encoding='utf-8', parse_dates=['Date'], dayfirst=True, index_col='Date')
fixed_df.head()
# Out:
#             Berri 1  Brébeuf  Côte-Sainte-Catherine  Maisonneuve 1  \
# Date
# 2012-01-01       35      NaN                      0             38
# 2012-01-02       83      NaN                      1             68
# 2012-01-03      135      NaN                      2            104
# 2012-01-04      144      NaN                      1            116
# 2012-01-05      197      NaN                      2            124
#
#             Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  St-Urbain
# Date
# 2012-01-01             51       26            10       16        NaN
# 2012-01-02            153       53             6       43        NaN
# 2012-01-03            248       89             3       58        NaN
# 2012-01-04            318      111             8       61        NaN
# 2012-01-05            330       97            13       95        NaN

# %%
fixed_df['Berri 1'].head()
# Out:
# Date
# 2012-01-01     35
# 2012-01-02     83
# 2012-01-03    135
# 2012-01-04    144
# 2012-01-05    197
# Name: Berri 1, dtype: int64

# %%
fixed_df['Berri 1'].plot()
plt.show()

# %%
fixed_df.plot(figsize=(15,10))
plt.show()
